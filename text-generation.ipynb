# %% [markdown]
# # Char-based text generation with LSTM

# %%
from collections import Counter

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %%
TRAIN_TEXT_FILE_PATH = '/content/ii_petrik.txt' #'train_text.txt'

with open(TRAIN_TEXT_FILE_PATH) as text_file:
    text_sample = text_file.readlines()
text_sample = ' '.join(text_sample)

def text_to_seq(text_sample):
    char_counts = Counter(text_sample)
    char_counts = sorted(char_counts.items(), key = lambda x: x[1], reverse=True)

    sorted_chars = [char for char, _ in char_counts]
    print(sorted_chars)
    char_to_idx = {char: index for index, char in enumerate(sorted_chars)}
    idx_to_char = {v: k for k, v in char_to_idx.items()}
    sequence = np.array([char_to_idx[char] for char in text_sample])

    return sequence, char_to_idx, idx_to_char

sequence, char_to_idx, idx_to_char = text_to_seq(text_sample)
# Out:
# [' ', 'о', 'е', 'т', 'и', 'а', 'н', 'с', 'р', 'в', 'л', 'к', '\n', 'м', 'п', 'у', 'д', 'ы', 'я', 'з', 'б', 'ь', 'г', 'ч', 'х', 'ж', 'ю', 'й', 'э', 'щ', 'ш', 'ц', 'ф', 'К', 'Н', '-', 'Д', 'S', 't', 'a', 'r', 'В', 'Э', 'И', 'Т', 'У', '0', 'А', 'С', 'Ч', 'П', 'Е', '3', '2', 'ё', '6', 'Б', 'Л', 'Я', '4', '5', 'М', 'D', 'ъ', '1', 'X', 'Р', 'О']

# %%
SEQ_LEN = 256
BATCH_SIZE = 16

def get_batch(sequence):
    trains = []
    targets = []
    for _ in range(BATCH_SIZE):
        batch_start = np.random.randint(0, len(sequence) - SEQ_LEN)
        chunk = sequence[batch_start: batch_start + SEQ_LEN]
        train = torch.LongTensor(chunk[:-1]).view(-1, 1)
        target = torch.LongTensor(chunk[1:]).view(-1, 1)
        trains.append(train)
        targets.append(target)
    return torch.stack(trains, dim=0), torch.stack(targets, dim=0)

# %%
def evaluate(model, char_to_idx, idx_to_char, start_text=' ', prediction_len=200, temp=0.3):
    hidden = model.init_hidden()
    idx_input = [char_to_idx[char] for char in start_text]
    train = torch.LongTensor(idx_input).view(-1, 1, 1).to(device)
    predicted_text = start_text

    _, hidden = model(train, hidden)

    inp = train[-1].view(-1, 1, 1)

    for i in range(prediction_len):
        output, hidden = model(inp.to(device), hidden)
        output_logits = output.cpu().data.view(-1)
        p_next = F.softmax(output_logits / temp, dim=-1).detach().cpu().data.numpy()
        top_index = np.random.choice(len(char_to_idx), p=p_next)
        inp = torch.LongTensor([top_index]).view(-1, 1, 1).to(device)
        predicted_char = idx_to_char[top_index]
        predicted_text += predicted_char

    return predicted_text

# %%
class TextRNN(nn.Module):

    def __init__(self, input_size, hidden_size, embedding_size, n_layers=1):
        super(TextRNN, self).__init__()

        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers

        self.encoder = nn.Embedding(self.input_size, self.embedding_size)
        self.lstm = nn.LSTM(self.embedding_size, self.hidden_size, self.n_layers)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(self.hidden_size, self.input_size)

    def forward(self, x, hidden):
        x = self.encoder(x).squeeze(2)
        out, (ht1, ct1) = self.lstm(x, hidden)
        out = self.dropout(out)
        x = self.fc(out)
        return x, (ht1, ct1)

    def init_hidden(self, batch_size=1):
        return (torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device),
               torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device))

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = TextRNN(input_size=len(idx_to_char), hidden_size=128, embedding_size=128, n_layers=2)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, amsgrad=True)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    patience=5,
    verbose=True,
    factor=0.5
)

n_epochs = 50000
loss_avg = []

for epoch in range(n_epochs):
    model.train()
    train, target = get_batch(sequence)
    train = train.permute(1, 0, 2).to(device)
    target = target.permute(1, 0, 2).to(device)
    hidden = model.init_hidden(BATCH_SIZE)

    output, hidden = model(train, hidden)
    loss = criterion(output.permute(1, 2, 0), target.squeeze(-1).permute(1, 0))

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    loss_avg.append(loss.item())
    if len(loss_avg) >= 50:
        mean_loss = np.mean(loss_avg)
        print(f'Loss: {mean_loss}')
        scheduler.step(mean_loss)
        loss_avg = []
        model.eval()
        predicted_text = evaluate(model, char_to_idx, idx_to_char)
        print(predicted_text)
# Out:
# Loss: 2.7149357843399047
#  верона вырые нак поторода в вы на примораторые в и выради поторатение на в торые вырабак накаторах систороны долесторые на проратение на вырате на потоление вырака примона которона поление на поторати
# Loss: 1.8875826478004456
#  нам постого протеина поками стероин в который нас уровня в это в который накоторый нас на который нас в вырабатывается в который протеина то на в протеина пормона который стероидных посто на то пример
# Loss: 1.4787632489204408
#  будет выработки то есть у внесть у них протеинов нас выработки в которые уровни холестерина и вы портизола в повышение воспалительно это показания тим начинает у них далее посто наблюдается тестостеро
# Loss: 1.2090504384040832
#  гормональной тестостерона и в конечно повышая снижение процесс воспалительные показания тестостерона и в конечно выработку местероталить выработку старение приводит к чем которые вырабатывается при ст
# Loss: 1.0201552844047546
#  же
#  помогают в конечно к как выработка
#  стероидных гормонов не набирая все это клетки сосудов и в конечно к чему в конечно же повышается они
#  прогестерона и эстрадиола и в конечном который переносит у
# Loss: 0.8900445508956909
#  воспаления очень низкие уровни холестерин и в коже свои гормона никуда этом у меня есть пормержание он может быть процесс воспаления активность процесс воспаления и старение прогестерона и в коже все
# Loss: 0.751143000125885
#  виде на постое
#  он может быть зависимым от
#  гормональной терапии и люди сдаются набирая не повышается применение того что раньше как на приводит к этому надо бороться со стероидные
#  гормональной терап
# Loss: 0.652809351682663
#  гормональной терапии им надо бороться со страдиола и прогестерона и вот это которые у нас приводит которые у нас находится он может быть зависимым от
#  от мапемварии у мужчин которые потому что они име
# Loss: 0.5604215294122696
#  воспаления и все эти примеры Ну например
#  кортизол и так далее но постоянно испытывают
#  отскок потому что они именно по
#  озвученным выше причинам которые переносит у нас холестерин у
#  человека конечно
# Loss: 0.5077902704477311
#  воспаления Дело в том что самое
#  процессов воспаления это не перехода холестерина в конечном итоге
#  определенов и старением в
#  первом закрепленном комментарии есть
#  снижение холестерин из-за этого взя
# Loss: 0.46815465688705443
#  воспаления и все эти как вдом на надо бороться
#  повышение уровня холестерина в принципе это такая внешняя
#  одинаковить выработки белка стар но как
#  выше фактора
#  интерлейкин 6 интерлейкин 1Б А все это
# Loss: 0.4181694954633713
#  воспалительные цитокины которые занимаются
#  выработка эстрадиола
#  но пока что у них не синтезируется
#  стероидные гормоны в разных частях нашего тестостерона или у женщин и
#  полена и при этом у него св
# Loss: 0.3822301667928696
#  воспаления которые занимаются
#  выработки тестостерона и эстрадиола и
#  Эстрадиол и далее у нас при снижении
#  образование
#  белка Старт так как только вы переступаете
#  определенные порог лет у вас начина
# Loss: 0.3575187069177628
#  виде жировых капелек или эфиров
#  холестерина не связаны с уровнями
#  тестостерона и эстрадиола и
#  прогестерона и при гненолона в головном
#  мозге и в результате этого
#  начинает накапливаться и вот поэто
# Loss: 0.3438159584999084
#  воспалительные цитокины которые будут
#  способны активизировать нам этот белок Star
#  ответственен еще и за обратный поток
#  холестерина и проверить
#  уровень их тестостерон лабораторно или
#  это клиническ
# Loss: 0.31909207105636594
#  видео
#  альдовой а также периферических
#  тканях Ну например в подкожной холестерина в
#  повысить выработку
#  белка стар но затовень выработка
#  детенизирующего гормона по механизму
#  отрицательная обратной
# Loss: 0.3074082452058792
#  препаратов у них
#  повышается также уровень и
#  лютеинизирующего гормона и фолликулов а Эстрадиол основоположником всего этого
#  хозяйства конечно же не доходит дело до
#  таких острых и плохих ситуаций но
# Loss: 0.2840009754896164
#  давагаи атем что у человека
#  вообще отсутствует выведен быть а также тот же прогестерона и прогестерона и эстрадиола и
#  таким образом у них просто наступают на горло себе А это всегда
#  заканчивается т
# Loss: 0.26943683475255964
#  воспаление стероидные
#  гормоны им надпочечниках либо он может быть зависим от
#  фолликула стимулирующего гормона Если речь
#  идет о биосинтезе эстрадиола прогестерона у женщин и в коже всех и
#  прогестер
# Loss: 0.27396431028842927
#  воспаления которые
#  повышая
#  лютеинизирующего гормона и фолликула
#  стимулирующего гормона Если
#  речь идет о биосинтезе эстрадиола
#  яичниках таким образом опять
#  запускать из холестерина и проверить
#  у
# Loss: 0.2533531844615936
#  видео
#  этом У меня все Позвольте сделать
#  заключительный вывод не надо бояться
#  сниженных
#  препаратов одним словом очень много дров но у вас
#  есть узкое место
#  это не позволяет повысить активность уже
# Loss: 0.24408009231090547
#  препаратами
#  эстрогенов и так далее для женщин но это
#  уже не тема сегодняшнего видео
#  Единственной
#  страдают от симптомов менопаузы именно
#  страдают от симптомов менопаузы именно
#  страдают от симптом
# Loss: 0.23232827216386795
#  воспаления и все
#  пожалуйста порочный Круг запущен на фоне
#  всего этого воспалительного безобразия у
#  человека конечно же снижается и уровень
#  вырабатывается при
#  гненолон а также Некоторое
#  количеств
# Loss: 0.23308215409517288
#  есть периферических
#  тканях Ну например в подкожной жировой
#  которые
#  повреждают окружающие ткани которые
#  привлекают другие воспалительные цитокины
#  такие вещества которые занимаются
#  выработкой стер
# Loss: 0.22190051436424255
#  гормоны у меня его и
#  так полно И падает выработка
#  детенизирующего гормона и
#  фолликулостимулирующего гормона и фолликула
#  стимулирующего гормона Если речь
#  идет о биосинтезе тестостерона в яичках
#  И
# Loss: 0.2207886579632759
#  есть довольно неприятные
#  вещи на этом всем Огромное спасибо
#  Украины слова героически он у
#  вас высокий Это не приведет ни к кому
#  снижению тестостерона и эстрадиола прогестерона если это мужчины
#  ил
# Loss: 0.20230259627103805
#  гени этого нам надо немножечко заглянуть в
#  биосинтез стероидных гормонов в
#  надпочечниках и в яичках у
#  мужчин и в яичниках у женщин и в
#  головном мозге и даже в ко
#  и это реакция перехода холестерин
# Loss: 0.19672078281641006
#  акотической работы а я в этом кое-что
#  понимаю и наконец Невозможно быть
#  здоровым и быть с избыточным весом иметь
#  большое количество тестостерона нам
#  для этого нужно взять группу людей с
#  высоким с
# Loss: 0.2077038413286209
#  воспаления и все
#  пожалуйста порочный Круг запущен на фоне
#  всего этого воспалительного безобразия у
#  человека конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  менее по мере на
# Loss: 0.20861076533794404
#  виде жировых капелек или эфиров
#  холестерина не связаны с уровнями
#  тестостерона и эстрадиола
#  яичниках таким образом под влиянием
#  гормонов гипофиза происходит первая реакция образование
#  при гненоло
# Loss: 0.19957659602165223
#  есть повышая не поводит активность выработки белка
#  Стар во всех клетках которые синтезируют
#  гормона стероидные либо в виде запасов в
#  виде жировых капелек или эфиров
#  холестерина неиспользованного в
# Loss: 0.18741559535264968
#  есть показания это
#  сниженные тестостерон лабораторно или
#  это клинические признаки недостатка
#  тестостерона А если же человек себе
#  просто вот хочет как-то
#  страдают от симптомов они хотят улучшить
#
# Loss: 0.1904256236553192
#  есть довольно неприятные
#  вещи на этом всем Огромное спасибо
#  Украины слова героическим украинскому
#  народу и хоть иногда то еще в климате
#  все мои консульта и вы время вспять то
#  у меня его и
#  так по
# Loss: 0.19723365008831023
#  ещи к увеличению процессов
#  хронического воспаления и все
#  пожалуйста порочный Круг запущен на фоне
#  всего этого воспалительного безобразия у
#  человека конечно же снижается и уровень
#  выработки белка
#
# Loss: 0.19503901958465575
#  есть довольно неприятные
#  вещи на этом всем Огромное спасибо
#  Украины слова героическим украинсим уровень и
#  лютеинизирующего гормона и
#  фолликула стимулирующего гормона Если
#  речь идет о биосинтезе т
# Loss: 0.1866186609864235
#  виде жировых капелек или эфиров
#  холестерина либо он может быть зависимым от
#  адрена кортикотропного гормона То есть
#  это гормон гипофиза который влияет на
#  биосинтез стероидных гормонов в
#  надпочечни
# Loss: 0.178631452023983
#  даванием собственного
#  тестостерона или у женщин Которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увеличение
#  выработки
#  альфа-тумар некротическо
# Loss: 0.17772607177495955
#  воспалительные цитокины которые
#  повреждают окружающие ткани которые
#  привлекают другие воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов ни
# Loss: 0.18260690808296204
#  возрасте это у новорожденных
#  прямо развивается у них наблюдается
#  повы уровня уровня холестерина лечение
#  процессов воспаления от склероз это как
#  раз то что действительно может развиться процесс вос
# Loss: 0.18182006537914275
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увел
# Loss: 0.17510223448276518
#  воспаления от склероз это как
#  раз то что действительно
#  высокое содержание холестерина
#  природно низкой
#  плотности которые у нас оседает еще и в
#  стенках сосудов в принципе это явление
#  до поры до вр
# Loss: 0.17406503170728682
#  воспаления и все
#  пожалуйста порочный Круг запущен на фоне
#  всего этого воспалительного безобразия у
#  человека конечно же снижается и уровень
#  выработки тестостерона и эстрадиола и
#  прогестерона и аль
# Loss: 0.1794610771536827
#  воспаления которые
#  ответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  менее по мере нашего старения К
#  сожалению активность выработки белка
#  Стар
# Loss: 0.17592884927988053
#  нечно же снижение уровня
#  холестерина всяческими способами либо
#  едой вы его можете ограничить и
#  навредить себе Либо вы это можете
#  сделать при помощи лекарственных
#  препаратов одним словом очень мно
# Loss: 0.15999388456344604
#  препаратов у
#  человека приводят снижению уровня
#  лютеинизирующего гормона по механизму
#  отрицательная обратной связи Вы вводите
#  тестостерон и в результате этого наш гипофиз
#  начинает вырабатывать бол
# Loss: 0.1652676686644554
#  воспаления Дело в том что существуют такие
#  рецепторы X которые находятся в ядре
#  клеток печени и кожи и стимуляция этих
#  рецепторов
#  ретиноидами например адапполеном о
#  котором я уже рассказывал рети
# Loss: 0.17339657932519914
#  еще
#  иметь высокое артериальное
#  давление многие люди безуспешно пытаются
#  бороться со своим давлением Таблетки не
#  помогают Таблетки не хотят принимать
#  поэтому у меня есть курс который
#  называется
#
# Loss: 0.1672704854607582
#  виде запасов в
#  виде жа эстрадиола прогестерона у них
#  повышается также уровень и
#  лютеинизирующего гормона и
#  фолликулостимулирующего гормона чтобы как-то
#  увеличить продукцию стероидных гормонов это
# Loss: 0.162824824154377
#  воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов низкой плотности вот того
#  самого плохого холестерина на
#  поверхности клетки это реакция я
# Loss: 0.15180760741233826
#  воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов низкой плотности то есть
#  хороший холестерин который уже и
#  забирает холестерин есть периф
# Loss: 0.15261775732040406
#  воспалительные клетки
#  развиваются воспаления и все
#  пожалуйстя
#  стероидные гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей
# Loss: 0.16496527403593064
#  по поводу
#  так называемой заместительной
#  гормональной терапии им надо срочно
#  давать жидкости давать срочно солевые
#  растворы надо срочно замещать гормоны
#  потому что у них не синтезируется
#  стероидн
# Loss: 0.161016743183136
#  жизниза гормонов гипофиза происходит активация
#  вот этого белка Star и именно белок Star
#  который переносит у нас холестерин из
#  клетки внутрь митохондрии где он превращается
#  повторюсь в пригненолон
# Loss: 0.15784485280513763
#  при снижении
#  уровня холестерина в крови
#  потому что у них действительно
#  высокое содержание либо тестостерона
#  либо женских половых гормонов но Давайте
#  посмотрим на первую группу У кого У нас
#  очень
# Loss: 0.15322480231523514
#  воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов низкой плотности то есть
#  хороший холестерин который уже и
#  забирает холестерин есть периф
# Loss: 0.14597994327545166
#  воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов низкой плотности вот того
#  стать суперменом при этом у него свой
#  собственный тестостерон
# Loss: 0.15873085603117942
#  воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липипиченьшения и все что
#  угодно и у вас не было никаких проблем А
#  после
#  40-50-60 стали нарастать вот
# Loss: 0.16976678848266602
#  вормации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте
#  предположить что
#  холестерин и будет приведет ни к кому
#  снижению тестостерона и эстрадиола
#  но п
# Loss: 0.17321988344192504
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления которые
#  ответственны отчасти за старение
#  организма
#  к заболеваниям суставов к Нейро
#  дегене по воплощению
# Loss: 0.17495407462120055
#  вормация этого
#  начинает накапливаться и вот поэтому у
#  мужчин которые проводятся не По
#  показаниям то есть показания это
#  сниженные тестостерон лабораторно или
#  это клинические признаки недостатка
#  т
# Loss: 0.17295552670955658
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления Дело в том что существуют такие
#  рецепторы X которые находятся вопредет ни как у нас
#  при старении синтезиро
# Loss: 0.17209734559059142
# Epoch 00062: reducing learning rate of group 0 to 5.0000e-03.
#  воспалительные цитокины которые
#  повреждают окружающие ткани которые
#  привлекают другие воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов ни
# Loss: 0.12529803052544594
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увел
# Loss: 0.10015762940049172
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 пол
# Loss: 0.09209605276584626
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 пол
# Loss: 0.08971008375287055
#  воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увеличение
#  выработки
#  альфа-тумар некротического фактора
#  интерлейкин 6 интерлейкин
# Loss: 0.08895356863737107
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления Дело в том что существуют такие
#  рецепторы X которые находятся в ядре
#  клеток печени и кожи и стимуляция эти
# Loss: 0.08706562757492066
#  жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются они
#  наступают на горло себе А это всегда
#  заканчивается тем что сила воли не
#  бесконечна и люди сд
# Loss: 0.08442564815282821
#  воспалительные цитокины которые
#  повреждают окружающие ткани которые
#  привлекают другие воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов ни
# Loss: 0.0853438612818718
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления Дело в том что
#  этот белок еще и воздействует на
#  макрофаги это клетки которые у нас
#  участвуют в иммунном о
# Loss: 0.08281969517469406
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увел
# Loss: 0.0816042260825634
#  воспалительные цитокины которые
#  повреждают окружающие ткани которые
#  привлекают другие воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов ни
# Loss: 0.08153660416603088
#  вот эти вет поэтому мы наблюдаем при снижении
#  уровня тестостерона повышение уровня
#  лютеинизирующего гормона у мужчин а при
#  менопаузе у женщин так как у них падает
#  выработка эстрадиола прогестерона
# Loss: 0.07960560381412506
#  воспалительные цитокины которые
#  повреждают окружающие ткани которые
#  привлекают другие воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов ни
# Loss: 0.07897524565458297
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности вот того
#
# Loss: 0.0786792878806591
#  воспаления от склероз это как
#  раз то что действительно может развиться
#  и снизить ваше качество жизни обусловить
#  деменцию импотенцию ампутации
#  конечностей
#  почечную недостаточность инфаркта
#  инсуль
# Loss: 0.07707667946815491
#  воспаления от склероз это как
#  раз то что действительно может развиться
#  и снизить ваше качество жизни обусловить
#  деменцию импотенцию ампутации
#  конечностей
#  почечную недостаточность инфаркта
#  инсуль
# Loss: 0.07644602701067925
#  жизни Каким бы
#  могли быть эти примеры Ну например Я
#  полагаю что можно взять людей у которых
#  низкий уровень холестерина и проверить
#  уровень их тестостерона если это мужчины
#  или эстрадиола или прог
# Loss: 0.07806406021118165
#  периферических
#  тканях Ну например в подкожной жировой
#  клетчатке и в коже там тоже
#  вырабатывается Эстрадиол но еще
#  интересно что биосинтез стероидных
#  гормонов идет и в головном мозге там
#  довольно
# Loss: 0.07594718530774117
#  последних достижений мировой
#  доказательной медицины которая касается
#  антирейтинга то есть борьбы со старением
#  в жизни Кроме того Невозможно быть
#  здоровым и иметь высокое артериальное
#  давление мно
# Loss: 0.07604560449719429
#  жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются они
#  наступают на горло себе А это всегда
#  заканчивается тем что сила воли не
#  бесконечна и люди сд
# Loss: 0.07540281005203724
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.0764624747633934
#  до
#  тестостерона или его препаратов у
#  человека приводят снижению уровня
#  лютеинизирующего гормона и
#  фолликулостимулирующего гормона Как вы
#  видите без толку все это Но как же
#  совсем этим бороться
#
# Loss: 0.07402736887335777
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 пол
# Loss: 0.07378260940313339
#  воспользованного в процессе
#  си для гормонов из клетки то есть тот
#  холестерин который не израсходовался
#  должен будет выведен быть из клетки
#  путем соединения его со специальными
#  белками в конечном
# Loss: 0.07401237599551677
#  гормона физиологических наблюдается
#  повы уровня уровня холестерина в крови
#  потому что у них как раз этот белок Star
#  он еще Работал бы но вы сами специально
#  его глушите путем того что употребляете
#
# Loss: 0.07355346843600273
#  первая реакция синтеза стероидных
#  гормонов одинаково во всех органах и
#  тканях где синтезируется стероидные
#  гормоны им надпочечниках и в яичках у
#  мужчин и в яичниках у женщин и в
#  головном мозге и
# Loss: 0.07144365832209587
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности вот того
#
# Loss: 0.07159864544868469
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.0729369891434908
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.07143222570419311
#  воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увеличение
#  выработки
#  альфа-тумар некротического фактора
#  интерлейкин 6 интерлейкин
# Loss: 0.07073307886719704
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности вот того
#
# Loss: 0.07030167125165462
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение холестерина именно по
#  озвученным выш
# Loss: 0.07070131823420525
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности
#  становит
# Loss: 0.07159385524690151
#  вот эти примеры Ну например Я
#  полагаю что можно взять людей у которых
#  низкий уровень холестерина и проверить
#  уровень их тестостерона если это мужчины
#  или эстрадиола или прогестерона если это
#  женщ
# Loss: 0.07014374844729901
#  воспалительного безобразия у
#  человека конечно же снижается и уровень
#  выработки тестостерона и эстрадиола у
#  женщин яичниках Да и в коже всех и
#  прогестерона и при гненолона в головном
#  мозге и в рез
# Loss: 0.07097274005413055
#  накровим снижение холестерина именно по
#  озвученным выше причинам для того чтобы
#  данное утверждение было вер то есть
#  снижение уровня холестерина ведет
#  неизбежно к падению тестостерона и
#  других сте
# Loss: 0.06948057785630227
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности
#  становит
# Loss: 0.06974174834787845
#  жирает повышая
#  лютеинизирующие фолликулостимулирующий
#  гормон или адрен аккортикотропный гормон
#  все равно это не вызовет такого ответа
#  как могло бы быть вызвано в молодости
#  вот поэтому мы наблюдае
# Loss: 0.07076022446155548
#  жизниза этого
#  начинает накапливаться и вот поэтому у
#  мужчин которые применяют заместительную
#  гормональную терапию не По показаниям в
#  дозах выше физиологических наблюдается
#  повы уровня уровня холе
# Loss: 0.06948385752737522
#  жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются они
#  наступают на горло себе А это всегда
#  заканчивается тем что сила воли не
#  бесконечна и люди сд
# Loss: 0.07145939819514752
#  жизни Кроме того Невозможно быть
#  здоровым и быть с избыточным весом иметь
#  большое количество жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются они
#
# Loss: 0.07088360585272312
#  воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увеличение
#  выработки
#  альфа-тумар некротического фактора
#  интерлейкин 6 интерлейкин
# Loss: 0.06909965492784977
#  жизни Каким бы
#  могли быть эти примеры Ну например Я
#  полагаю что можно взять людей у которых
#  низкий уровень холестерина и проверить
#  уровень их тестостерона если это мужчины
#  или эстрадиола или прог
# Loss: 0.06825572088360786
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.06867258548736573
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности
#  становит
# Loss: 0.06888876371085643
#  жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются они
#  наступают на горло себе А это всегда
#  заканчивается тем что сила воли не
#  бесконечна и люди сд
# Loss: 0.0679222758859396
#  жира есть периферических
#  тканей вот я специально нашел картинку
#  где показана Что происходит с клеткой
#  Когда в ней отсутствуют белок Star с
#  левой стороны нормальная клетка А вот
#  самая Крайняя прав
# Loss: 0.06815238922834396
#  жизни Каким бы
#  могли быть эти примеры Ну например Я
#  полагаю что можно взять людей у которых
#  низкий уровень холестерина и проверить
#  уровень их тестостерона если это мужчины
#  или эстрадиола или прог
# Loss: 0.06691096730530262
#  видео а также
#  вырабатывают про воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недоста
# Loss: 0.06781640917062759
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.06814539931714535
#  воспаления от склероз это как
#  раз то что действительно может развиться
#  и снизить ваше качество жизни обусловить
#  деменцию импотенцию ампутации
#  конечностей
#  почечную недостаточность инфаркта
#  инсуль
# Loss: 0.06734915994107724
#  видеожа
#  которые адекватные люди
#  сегодня обсудим довольно
#  распространённое мнение о том что
#  снижение уровня холестерина в крови
#  неизбежно ведёт к падению уровня
#  астероидных гормонов в частности
#
# Loss: 0.066751359552145
#  периферических
#  тканях Ну например в подкожной жировой
#  клетчатке и в коже там тоже
#  вырабатывается Эстрадиол но еще
#  интересно что биосинтез стероидных
#  гормонов идет и в головном мозге там
#  довольно
# Loss: 0.06545631118118762
#  воспользованного в процессе
#  си для гормонов из клетки то есть тот
#  холестерин который не израсходовался
#  должен будет выведен быть из клетки
#  путем соединения его со специальными
#  белками в конечном
# Loss: 0.0662528944760561
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности
#  становит
# Loss: 0.06738757140934468
#  периферических
#  тканях Ну например в подкожной жировой
#  клетчатке и в коже там тоже
#  вырабатывается Эстрадиол но еще
#  интересно что биосинтез стероидных
#  гормонов идет и в головном мозге там
#  довольно
# Loss: 0.0672709197551012
#  перехода холестерина внутрь
#  митохондрии где он превращается
#  повторюсь в пригненолон а транспортом
#  управляет белок который носит название
#  Стар по английской аббревиатуре
#  астероида дженнинг
#  или ст
# Loss: 0.06773232832551003
#  возрасте это у новорожденных
#  прямо развивается у них наблюдается
#  практически очень низкие концентрации
#  кортизола альдостеро естественно
#  тестостерона прогестерона эстрадиола и
#  таким образом у них
# Loss: 0.0663923417031765
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.06669887825846672
# Epoch 00121: reducing learning rate of group 0 to 2.5000e-03.
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности вот того
#
# Loss: 0.06426428519189357
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности
#  становит
# Loss: 0.060546700209379196
#  к этому вы получаете
#  низкие уровни тестостерона низкие уровни
#  эстрадиола прогестерона у женщин То есть
#  у них начинается менопауза у мужчины и
#  начинается андропауза Позвольте мне
#  небольшое отступл
# Loss: 0.06010117314755917
#  возрасте это у новорожденных
#  прямо развивается у них наблюдается
#  практически очень низкие концентрации
#  кортизола альдостеро естественно
#  тестостерона прогестерона эстрадиола и
#  таким образом у них
# Loss: 0.06110226102173329
#  жизни Каким бы
#  могли быть эти примеры Ну например Я
#  полагаю что можно взять людей у которых
#  низкий уровень холестерина и проверить
#  уровень их тестостерона если это мужчины
#  или эстрадиола или прог
# Loss: 0.060486989915370944
#  воже что холестерин у нас находится в тех
#  клетках которые синтезируют
#  гормона стероидные либо в виде запасов в
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтез
# Loss: 0.05870736427605152
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.06051934689283371
#  гормоны
#  низкой плотности
#  становится очень даже обидным и
#  начинается процесс образования
#  атеросклеротических бляшек а следует еще
#  и учесть что при снижении активности
#  белка стар у нас снижается з
# Loss: 0.058445225805044174
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.059613673835992816
#  до
#  таких острых и плохих ситуаций но тем не
#  менее по мере нашего старения К
#  сожалению активность выработки белка
#  Стар во всех клетках которые занимаются
#  выработкой стероидных гормонов этот
#  проце
# Loss: 0.05794211223721504
#  гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 полена вам надо получить
#  большое здание и у вас есть большой
#  запас дров ну скажем вам привезли дв
# Loss: 0.058797286823391914
#  до
#  таких острых и плохих ситуаций но тем не
#  менее по мере нашего старения К
#  сожалению активность выработки белка
#  Стар во всех клетках которые занимаются
#  выработкой стероидных гормонов этот
#  проце
# Loss: 0.0578067222982645
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05724055640399456
#  прогестерона если это
#  женщины И наоборот если мы хотим
#  подтвердить версию что холестерин Нам
#  очень нужен для того чтобы выработать
#  достаточное количество тестостерона нам
#  для этого нужно взять гр
# Loss: 0.057801550328731535
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.058618166521191596
#  жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются они
#  наступают на горло себе А это всегда
#  заканчивается тем что сила воли не
#  бесконечна и люди сд
# Loss: 0.057067769765853885
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.059063816368579866
#  жира есть периферических
#  тканей вот я специально нашел картинку
#  где показана Что происходит с клеткой
#  Когда в ней отсутствуют белок Star с
#  левой стороны нормальная клетка А вот
#  самая Крайняя прав
# Loss: 0.058206367045640944
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увел
# Loss: 0.05683377549052238
#  жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются они
#  наступают на горло себе А это всегда
#  заканчивается тем что сила воли не
#  бесконечна и люди сд
# Loss: 0.05694616623222828
#  жизни Каким бы
#  могли быть эти примеры Ну например Я
#  полагаю что можно взять людей у которых
#  низкий уровень холестерина и проверить
#  уровень их тестостерона если это мужчины
#  или эстрадиола или прог
# Loss: 0.058370661959052085
#  том
#  что первая реакция синтеза стероидных
#  гормонов одинаково во всех органах и
#  тканях где синтезируется стероидные
#  гормоны им надпочечниках и в яичках у
#  мужчин и в яичниках у женщин и в
#  головном
# Loss: 0.05613689623773098
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05693249106407165
#  воспалительные цитокины которые
#  повреждают окружающие ткани которые
#  привлекают другие воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу холестерин
#  липопротеинов ни
# Loss: 0.05756804659962654
#  жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются они
#  наступают на горло себе А это всегда
#  заканчивается тем что сила воли не
#  бесконечна и люди сд
# Loss: 0.0565108785033226
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05777334727346897
#  возрасте это у новорожденных
#  прямо развивается у них наблюдается
#  практически очень низкие концентрации
#  кортизола альдостеро естественно
#  тестостерона прогестерона эстрадиола и
#  таким образом у них
# Loss: 0.056238261088728904
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05581165246665478
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.056998366862535475
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.0561767578870058
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности
#  становит
# Loss: 0.056148496940732005
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05604203514754772
#  до
#  таких острых и плохих ситуаций но тем не
#  менее по мере нашего старения К
#  сожалению активность выработки белка
#  Стар во всех клетках которые занимаются
#  выработкой стероидных гормонов этот
#  проце
# Loss: 0.05560240112245083
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.054708689972758295
#  гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 полена вам надо получить
#  большое здание и у вас есть большой
#  запас дров ну скажем вам привезли дв
# Loss: 0.05658923424780369
#  гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 полена вам надо получить
#  большое здание и у вас есть большой
#  запас дров ну скажем вам привезли дв
# Loss: 0.0560907106846571
#  гормоны им надпочечниках и в яичках у
#  мужчин и в яичниках у женщин и в
#  головном мозге и даже в ко
#  и это реакция перехода холестерина в
#  пригненолон Вот это реакция является
#  лимитирующим звеном а о
# Loss: 0.055104952305555344
#  гормоны у меня его и
#  так полно И падает выработка
#  детенизирующего гормона гипофизом а это
#  в свою очередь к чему приводит конечно к
#  угнетению белка старта то есть
#  наблюдается снижение перехода
#  хо
# Loss: 0.05606988474726677
#  со страдиолом и
#  прогестероном все в полном порядке и
#  наоборот как только вы переступаете
#  определенные порог лет у вас начинают
#  неизбежно повышаться холестерин вы
#  толстеете вдобавок к этому вы пол
# Loss: 0.05742266781628132
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05586338818073273
# Epoch 00161: reducing learning rate of group 0 to 1.2500e-03.
#  возрасте это у новорожденных
#  прямо развивается у них наблюдается
#  практически очень низкие концентрации
#  кортизола альдостеро естественно
#  тестостерона прогестерона эстрадиола и
#  таким образом у них
# Loss: 0.0551586988568306
#  гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 полена вам надо получить
#  большое здание и у вас есть большой
#  запас дров ну скажем вам привезли дв
# Loss: 0.0541462766379118
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05318518370389938
#  до
#  таких острых и плохих ситуаций но тем не
#  менее по мере нашего старения К
#  сожалению активность выработки белка
#  Стар во всех клетках которые занимаются
#  выработкой стероидных гормонов этот
#  проце
# Loss: 0.05459050595760345
#  до
#  такое
#  аутосомно рецессивное заболевание
#  которое проявляется тем что у человека
#  вообще отсутствует биосинтез стероидных
#  гормонов Это заболевание называется
#  липоидная форма врожденной
#  надпочеч
# Loss: 0.0535389019548893
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05400417000055313
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05435764148831367
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.053550884574651715
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05377101935446262
# Epoch 00170: reducing learning rate of group 0 to 6.2500e-04.
#  воспалительные цитокины
#  такие вещества которые запускают
#  процессы хронического воспаления которые
#  ответственны отчасти за старение
#  организма в частности при недостатке
#  белка Стар наблюдается увел
# Loss: 0.05313215859234333
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05233561187982559
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.053206351101398465
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.053274032697081565
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05151463694870472
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.052746529057621956
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности
#  становит
# Loss: 0.05296099968254566
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.052234467417001725
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05213207133114338
#  по сути это пошаговая
#  доступная инструкция по воплощению самых
#  последних достижений мировой
#  доказательной медицины которая касается
#  антирейтинга то есть борьбы со старением
#  в жизни Кроме того Нев
# Loss: 0.05157339841127396
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.052989949733018876
# Epoch 00181: reducing learning rate of group 0 to 3.1250e-04.
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05195871464908123
#  есть довольно неприятные
#  вещи на этом всем Огромное спасибо
#  Украины слова героическим украинскому
#  народу и хоть иногда то еще в климате
#  все мои консультации это обследование
#  быстро что не для рис
# Loss: 0.05165604755282402
#  перементе
#  Кроме того Невозможно быть
#  здоровым и быть с избыточным весом иметь
#  большое количество жира Многие люди это
#  понимают борются но постоянно испытывают
#  отскок потому что они именно борются
# Loss: 0.05183282770216465
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.052160666286945344
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05150108143687248
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05103222578763962
#  возрасте это у новорожденных
#  прямо развивается у них наблюдается
#  практически очень низкие концентрации
#  кортизола альдостеро естественно
#  тестостерона прогестерона эстрадиола и
#  таким образом у них
# Loss: 0.050913801044225694
#  виде жировых капелек или эфиров
#  холестерина либо он может в этих же
#  клетках и синтезироваться либо он
#  захватывается из кровотока при помощи
#  при соединении
#  липопротеинов низкой плотности
#  становит
# Loss: 0.051978269293904304
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.051702211499214175
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05093575119972229
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.051670728474855425
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.051292319744825364
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05012300372123718
#  до
#  такое
#  аутосомно рецессивное заболевание
#  которое проявляется тем что у человека
#  вообще отсутствует биосинтез стероидных
#  гормонов Это заболевание называется
#  липоидная форма врожденной
#  надпочеч
# Loss: 0.050210383981466294
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05163485273718834
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05132790744304657
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05098467774689198
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05082032591104507
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05206698976457119
# Epoch 00200: reducing learning rate of group 0 to 1.5625e-04.
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.051341476738452914
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.051792270615696905
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05042125627398491
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.050598967522382736
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.051595843508839605
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05099154338240623
# Epoch 00206: reducing learning rate of group 0 to 7.8125e-05.
#  возрастным болезням хотите полноценно
#  жить даже будучи в преклонном возрасте а
#  может быть даже вернуть время вспять то
#  у меня есть курс который называется Как
#  победить старение практическое
#  руков
# Loss: 0.05087460547685623
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05111285068094731
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05101331949234009
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
# ...
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05094171710312367
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.050554189160466195
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.050685961693525315
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.0505364290624857
#  до
#  такое
#  аутосомно рецессивное заболевание
#  которое проявляется тем что у человека
#  вообще отсутствует биосинтез стероидных
#  гормонов Это заболевание называется
#  липоидная форма врожденной
#  надпочеч
# Loss: 0.050996670648455616
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05108089566230774
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05081341192126274
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.051194308698177336
#  возрастным болезням хотите полноценно
#  жить даже будучи в преклонном возрасте а
#  может быть даже вернуть время вспять то
#  у меня есть курс который называется Как
#  победить старение практическое
#  руков
# Loss: 0.05099054537713528
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.050903596803545954
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05154323823750019
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05193242438137531
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.0512982801347971
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05106586910784244
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.04979774981737137
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.051260976344347
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.04997053883969784
#  переменению тестостерона и других стероидных
#  гормонов Давайте разберемся на самом
#  деле связаны они все-таки или нет И есть
#  ли под этим какая-нибудь основа для
#  этого нам надо немножечко заглянуть в
# Loss: 0.050513513907790186
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.050295919254422186
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.050712872371077536
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05094365641474724
#  гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 полена вам надо получить
#  большое здание и у вас есть большой
#  запас дров ну скажем вам привезли дв
# Loss: 0.05059023000299931
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05096666917204857
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05065858319401741
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.04976611636579037
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05120421856641769
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05109596975147724
#  есть довольно неприятные
#  вещи на этом всем Огромное спасибо
#  Украины слова героическим украинскому
#  народу и хоть иногда то еще в климате
#  все мои консультации это обследование
#  быстро что не для рис
# Loss: 0.050586876794695854
#  том
#  что по тем причинам которые я описал
#  повышение уровня холестерина лечение
#  процессов воспаления от склероз это как
#  раз то что действительно может развиться
#  и снизить ваше качество жизни обусло
# Loss: 0.0506615399569273
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05125650085508823
#  препаратов у
#  человека приводят снижению уровня
#  лютеинизирующего гормона по механизму
#  отрицательная обратной связи Вы вводите
#  тестостерон организм Ну зачем мне еще
#  вырабатывать свои гормоны у меня
# Loss: 0.05051227800548077
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05109904587268829
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05125693492591381
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05055164724588394
#  гормоны Но
#  не все так просто представим себе что у
#  вас есть маленькая печка в которую
#  влезают 2-3 полена вам надо получить
#  большое здание и у вас есть большой
#  запас дров ну скажем вам привезли дв
# Loss: 0.051400154381990436
#  гормоны им надпочечниках и в яичках у
#  мужчин и в яичниках у женщин и в
#  головном мозге и даже в ко
#  и это реакция перехода холестерина в
#  пригненолон Вот это реакция является
#  лимитирующим звеном а о
# Loss: 0.049781821966171265
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05116162769496441
#  собственный тестостерон еще более-менее
#  на нормальном уровне к чему это приводит
#  высокие сверх физиологичные дозы
#  тестостерона или его препаратов у
#  человека приводят снижению уровня
#  лютеинизирующ
# Loss: 0.05031522020697594
#  переменению тестостерона и других стероидных
#  гормонов Давайте разберемся на самом
#  деле связаны они все-таки или нет И есть
#  ли под этим какая-нибудь основа для
#  этого нам надо немножечко заглянуть в
# Loss: 0.05047047451138496
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05054974153637886
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.051049863919615746
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.050399266853928565
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05151237748563289
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.051091946959495545
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05158577188849449
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05117452636361122
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05127706423401832
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05054898381233215
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05059253372251987
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05083008147776127
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.05101156786084175
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05095341108739376
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.05015026658773422
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.050541694164276126
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.04996182478964329
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.04950858511030674
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# Loss: 0.051120251268148426
#  до
#  такой информации К сожалению она
#  поступает не только от обывателей но и
#  от некоторых врачей поэтому Давайте с
#  вами разберемся насколько такое
#  утверждение правдиво и надо ли опасаться
#  снижение
# Loss: 0.0508045744150877
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.05152713477611542
#  гормоны в результате того что
#  есть генетический дефект отсутствует
#  образование
#  белкастар соответственно у взрослых
#  людей конечно же не доходит дело до
#  таких острых и плохих ситуаций но тем не
#  ме
# Loss: 0.050832625404000284
#  жира то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас о
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-184f18a9bdfb> in <cell line: 17>()
#      26
#      27     loss.backward()
# ---> 28     optimizer.step()
#      29     optimizer.zero_grad()
#      30
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     371                             )
#     372
# --> 373                 out = func(*args, **kwargs)
#     374                 self._optimizer_step_code()
#     375
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      74             torch.set_grad_enabled(self.defaults['differentiable'])
#      75             torch._dynamo.graph_break()
# ---> 76             ret = func(self, *args, **kwargs)
#      77         finally:
#      78             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in step(self, closure)
#     161                 state_steps)
#     162
# --> 163             adam(
#     164                 params_with_grad,
#     165                 grads,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     309         func = _single_tensor_adam
#     310
# --> 311     func(params,
#     312          grads,
#     313          exp_avgs,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     507
#     508         torch._foreach_mul_(device_exp_avg_sqs, beta2)
# --> 509         torch._foreach_addcmul_(device_exp_avg_sqs, device_grads, device_grads, 1 - beta2)
#     510
#     511         # Delete the local intermediate since it won't be used anymore to save on peak memory
#
# KeyboardInterrupt:

# %%
model.eval()

print(evaluate(
    model,
    char_to_idx,
    idx_to_char,
    temp=0.3,
    prediction_len=1000,
    start_text='альфа'
    )
)
# Out:
# альфатоступять то есть жир
#  оттуда никуда не удаляется и то же самое
#  происходит кстати и с макрофагами так
#  как макрофаги способны захватывать
#  липиды холестерин липопротеинов низкой
#  плотности которые у нас оседает еще и в
#  стенках сосудов в принципе это явление
#  до поры до времени
#  видна до тех пор пока сосудистая стенка
#  не воспалена а воспаляется она потому
#  что накопившиеся плохой холестерин
#  стенки сосудов захватывается макрофагами
#  макрофаги накапливают в себе эти зерна
#  липидов и холестерина и если нет белка
#  Star то никуда этот холестерин и липиды
#  не деваются макрофагах накапливаются эти
#  липиды они превращаются в пенистые
#  клетки потому что они под микроскопом
#  похожи на пену из-за того что там внутри
#  много условно жира и вот эти пенистые
#  клетки как раз являются тем фактором
#  которые активно вырабатывают
#  воспалительные цитокины которые
#  повреждают окружающие ткани которые
#  привлекают другие воспалительные клетки
#  развиваются воспаление стенок сосудов и
#  безобидный поначалу хо
